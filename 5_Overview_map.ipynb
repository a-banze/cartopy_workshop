# %% [markdown]
# ## Chart with map inset
#
# Add a map inset for a chart or another map (overview map).

# %%
import cartopy.mpl.geoaxes
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import numpy as np
import cartopy.crs as ccrs

fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot()
ax.plot(np.random.rand(10))
ax.set_ylim(0,1.4)

inset = inset_axes(ax, width='35%', height='25%', loc='upper right', 
                   axes_class=cartopy.mpl.geoaxes.GeoAxes, 
                   axes_kwargs=dict(map_projection=ccrs.PlateCarree()))

inset.coastlines()
# Out:
# /localhome/banz_ar/.local/lib/python3.10/site-packages/cartopy/mpl/geoaxes.py:394: UserWarning: The `map_projection` keyword argument is deprecated, use `projection` to instantiate a GeoAxes instead.
#   warnings.warn("The `map_projection` keyword argument is "
